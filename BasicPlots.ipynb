# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
a = np.arange(0,100,1)

# %%
b=np.sin(a)

# %%
plt.figure(figsize=(12,6))
plt.plot(b)
plt.title("Simple sin(x) plot")
plt.grid()
